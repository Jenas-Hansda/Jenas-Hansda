# %%
pip install tensorflow
# Out:
# ...
#   Using cached setuptools-69.2.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#      ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#      ---------------------------------------- 46.2/46.2 kB 2.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/377.1 MB ? eta -:--:--
#    ---------------------------------------- 0.6/377.1 MB 17.5 MB/s eta 0:00:22
#    ---------------------------------------- 1.0/377.1 MB 31.7 MB/s eta 0:00:12
#    ---------------------------------------- 1.6/377.1 MB 16.7 MB/s eta 0:00:23
#    ---------------------------------------- 2.0/377.1 MB 12.9 MB/s eta 0:00:30
#    ---------------------------------------- 2.4/377.1 MB 12.6 MB/s eta 0:00:30
#    ---------------------------------------- 2.5/377.1 MB 10.6 MB/s eta 0:00:36
#    ---------------------------------------- 2.9/377.1 MB 10.2 MB/s eta 0:00:37
# ...
